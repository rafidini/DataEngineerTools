# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
db_series = client.series

# %%
collection_kickstarter = db_series["kickstarter"]
collection_kickstarter.delete_many({})

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'series']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv", index_col="ID")
df_ks = df_ks.rename(columns={"ID":"_id"})
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                                          name        category  \
# ID
# 872782264     Scott Cooper's Solo CD "A Leg Trick" (Canceled)            Rock
# 1326492673                                    Ohceola jewelry         Fashion
# 1688410639  Sluff Off & Harald: Two latest EGGs are Classi...  Tabletop Games
# 156812982   SketchPlanner: Create and Plan- all in one bea...       Art Books
# 1835968190    Proven sales with custom motorcycle accessories       Sculpture
#
#            main_category currency    deadline   goal             launched  \
# ID
# 872782264          Music      USD  2011-09-16   2000  2011-08-17 06:31:31
# 1326492673       Fashion      USD  2012-08-22  18000  2012-07-23 20:46:48
# 1688410639         Games      USD  2016-07-19   2000  2016-07-01 21:55:54
# 156812982     Publishing      USD  2017-09-27  13000  2017-08-28 15:47:02
# 1835968190           Art      CAD  2016-02-24   5000  2016-01-25 17:37:10
#
#            pledged       state backers country usd pledged  usd_pledged_real
# ID
# 872782264     1145    canceled      24      US        1145       1145.000000
# 1326492673    1851      failed      28      US        1851       1851.000000
# 1688410639    7534  successful     254      US        3796       7534.000000
# 156812982    16298  successful     367      US        2670      16298.000000
# 1835968190       1      failed       1      CA    0.708148          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['launched', 'state', 'country', 'usd_pledged_real'], dtype='object')

# %% [markdown]
# ## Question 0

# %%
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 872782264 to 891117261
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              149998 non-null  object
#  1   category          150000 non-null  object
#  2   main_category     150000 non-null  object
#  3   currency          150000 non-null  object
#  4   deadline          150000 non-null  object
#  5   goal              150000 non-null  object
#  6   launched          150000 non-null  object
#  7   pledged           150000 non-null  object
#  8   state             150000 non-null  object
#  9   backers           150000 non-null  object
#  10  country           150000 non-null  object
#  11  usd pledged       148518 non-null  object
#  12  usd_pledged_real  150000 non-null  float64
# dtypes: float64(1), object(12)
# memory usage: 16.0+ MB

# %% [markdown]
# ### Netoyer les données

# %%
def what_types(df, column):
    types = set()
    df[column].apply(lambda x: types.add(type(x)))
    return types

# %%
def to_another_type(value, ptype):
    if not isinstance(value, ptype):
        return None
    return value

# %%
# 'launched' & 'deadline' columns

def to_datetime(value):
    try:
        return pd.to_datetime(value)
    except:
        return None
    
columns = ["launched", "deadline"]
for col in columns:
    df_ks[col] = df_ks[col].apply(to_datetime)

# %%
# 'state' & 'country' columns

columns = ["state", "country"]
for col in columns:
    df_ks[col] = df_ks[col].apply(lambda x:to_another_type(x, str)).astype("category")

# %%
# 'usd_pledged_real' column

df_ks['usd_pledged_real'] = df_ks['usd_pledged_real'].astype("float64")

# %%
# integers/float type columns

columns = ["goal", "pledged", "backers", "usd pledged"]
for col in columns:
    print("in {} : {}".format(col, what_types(df_ks, col)))
# Out:
# in goal : {<class 'str'>, <class 'float'>}
# in pledged : {<class 'str'>, <class 'float'>}
# in backers : {<class 'str'>, <class 'int'>}
# in usd pledged : {<class 'str'>, <class 'float'>}

# %%
# float type columns

columns = ["goal", "pledged", "usd pledged"]

for col in columns:
    df_ks[col] = df_ks[col].apply(lambda x: to_another_type(x, float))
    df_ks[col] = df_ks[col].fillna(0.0)
    df_ks[col] = df_ks[col].astype("float64")

# %%
def change_backers(value):
    if isinstance(value, str):
        try:
            return int(value)
        except:
            return 0
    return value

df_ks["backers"] = df_ks["backers"].apply(change_backers)
df_ks["backers"] = df_ks["backers"].astype("int64")

# %%
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 872782264 to 891117261
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              149998 non-null  object
#  1   category          150000 non-null  object
#  2   main_category     150000 non-null  object
#  3   currency          150000 non-null  object
#  4   deadline          149999 non-null  datetime64[ns]
#  5   goal              150000 non-null  float64
#  6   launched          149999 non-null  datetime64[ns]
#  7   pledged           150000 non-null  float64
#  8   state             150000 non-null  category
#  9   backers           150000 non-null  int64
#  10  country           150000 non-null  category
#  11  usd pledged       150000 non-null  float64
#  12  usd_pledged_real  150000 non-null  float64
# dtypes: category(2), datetime64[ns](2), float64(4), int64(1), object(4)
# memory usage: 14.0+ MB

# %%
df_ks.head()
# Out:
#                                                          name        category  \
# ID
# 872782264     Scott Cooper's Solo CD "A Leg Trick" (Canceled)            Rock
# 1326492673                                    Ohceola jewelry         Fashion
# 1688410639  Sluff Off & Harald: Two latest EGGs are Classi...  Tabletop Games
# 156812982   SketchPlanner: Create and Plan- all in one bea...       Art Books
# 1835968190    Proven sales with custom motorcycle accessories       Sculpture
#
#            main_category currency   deadline     goal            launched  \
# ID
# 872782264          Music      USD 2011-09-16   2000.0 2011-08-17 06:31:31
# 1326492673       Fashion      USD 2012-08-22  18000.0 2012-07-23 20:46:48
# 1688410639         Games      USD 2016-07-19   2000.0 2016-07-01 21:55:54
# 156812982     Publishing      USD 2017-09-27  13000.0 2017-08-28 15:47:02
# 1835968190           Art      CAD 2016-02-24   5000.0 2016-01-25 17:37:10
#
#             pledged       state  backers country  usd pledged  \
# ID
# 872782264    1145.0    canceled       24      US  1145.000000
# 1326492673   1851.0      failed       28      US  1851.000000
# 1688410639   7534.0  successful      254      US  3796.000000
# 156812982   16298.0  successful      367      US  2670.000000
# 1835968190      1.0      failed        1      CA     0.708148
#
#             usd_pledged_real
# ID
# 872782264        1145.000000
# 1326492673       1851.000000
# 1688410639       7534.000000
# 156812982       16298.000000
# 1835968190          0.738225

# %%
df_ks.isna().sum()
# Out:
# name                2
# category            0
# main_category       0
# currency            0
# deadline            1
# goal                0
# launched            1
# pledged             0
# state               0
# backers             0
# country             0
# usd pledged         0
# usd_pledged_real    0
# dtype: int64

# %%
df_ks["name"] = df_ks["name"].fillna("?")
df_ks["deadline"] = df_ks["deadline"].fillna("?")
df_ks["launched"] = df_ks["launched"].fillna("?")

# %% [markdown]
# ### Importer les données

# %%
collection_kickstarter.insert_many(df_ks.to_dict('records'))

# %%
db_series.list_collection_names()
# Out:
# ['youtube', 'kickstarter', '{query :{gender:"Male"}, out:"sumAge"}', 'peaky']

# %%
collection_kickstarter.find_one()
# Out:
# {'_id': ObjectId('5fc50d4aff232a381ca6b6d1'),
#  'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#  'category': 'Rock',
#  'main_category': 'Music',
#  'currency': 'USD',
#  'deadline': datetime.datetime(2011, 9, 16, 0, 0),
#  'goal': 2000.0,
#  'launched': datetime.datetime(2011, 8, 17, 6, 31, 31),
#  'pledged': 1145.0,
#  'state': 'canceled',
#  'backers': 24,
#  'country': 'US',
#  'usd pledged': 1145.0,
#  'usd_pledged_real': 1145.0}

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Récupérer les 5 projets ayant reçu le plus de promesse de dons.

# %%
n = 5
cursor = collection_kickstarter.find({}).limit(n).sort([("pledged", -1)])

for e in cursor:
    print(e["name"])
    print(e["pledged"])
    print()
# Out:
# The Everyday Backpack, Tote, and Sling
# 6565782.5
#
# Pono Music - Where Your Soul Rediscovers Music
# 6225354.98
#
# The Veronica Mars Movie Project
# 5702153.38
#
# Zombicide: Black Plague
# 4079204.52
#
# The Dash ï¿½ Wireless Smart In Ear Headphones
# 3390551.0

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Compter le nombre de projets ayant atteint leur but.

# %%
# successful : state

# %%
cursor = collection_kickstarter.find({"state":"successful"})

len(list(cursor))
# Out:
# 53040

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Compter le nombre de projets pour chaque catégorie.

# %%
cursor = collection_kickstarter.aggregate([{"$group" : {"_id" : "$category", "counted" : {"$sum" : 1}}}])

{e["_id"]:e["counted"] for e in cursor}
# Out:
# {"Farmer's Markets": 175,
#  'Wearables': 508,
#  'Sculpture': 737,
#  'Childrenswear': 192,
#  'Design': 1641,
#  'Live Games': 394,
#  'Tabletop Games': 5581,
#  'Technology': 2690,
#  'Footwear': 379,
#  'DIY': 480,
#  'Kids': 109,
#  'Calendars': 112,
#  'Indie Rock': 2192,
#  'Video': 147,
#  'Typography': 44,
#  'Crochet': 61,
#  'Mixed Media': 1118,
#  'Latin': 63,
#  'Animals': 97,
#  'Stationery': 90,
#  'Video Games': 4799,
#  "Children's Books": 2686,
#  'Architecture': 300,
#  'Interactive Design': 146,
#  'Action': 282,
#  'Poetry': 532,
#  'Letterpress': 24,
#  'Audio': 164,
#  'Fantasy': 132,
#  'Drinks': 995,
#  'Mobile Games': 650,
#  'Flight': 158,
#  'Photography': 2239,
#  'Performances': 414,
#  'Knitting': 78,
#  'Family': 130,
#  'Weaving': 38,
#  'Theater': 2786,
#  'Conceptual Art': 393,
#  'Civic Design': 130,
#  'Graphic Novels': 702,
#  'Pottery': 40,
#  'Restaurants': 1089,
#  'Hip-Hop': 1555,
#  'Nonfiction': 3390,
#  'Art Books': 1065,
#  'Playing Cards': 963,
#  'Woodworking': 433,
#  'Film & Video': 4003,
#  'Sound': 255,
#  'Horror': 525,
#  'Vegan': 229,
#  'Installations': 178,
#  'Residencies': 32,
#  'Grace is Leaving': 1,
#  'Comedy': 923,
#  'Ready-to-wear': 332,
#  'Gadgets': 1210,
#  'Puzzles': 95,
#  'Comics': 1931,
#  'Anthologies': 300,
#  'Webseries': 2316,
#  'Painting': 1288,
#  'Publishing': 2332,
#  'Periodicals': 517,
#  'Science Fiction': 274,
#  'Digital Art': 524,
#  'Metal': 274,
#  'Journalism': 672,
#  'Camera Equipment': 165,
#  'Software': 1194,
#  'Fiction': 3703,
#  'Academic': 367,
#  'Electronic Music': 858,
#  'Makerspaces': 91,
#  'Print': 288,
#  'World Music': 850,
#  'Music Videos': 299,
#  'Fabrication Tools': 96,
#  'Festivals': 313,
#  'Movie Theaters': 90,
#  'Crafts': 1834,
#  'Fine Art': 291,
#  'Spaces': 331,
#  'Cookbooks': 217,
#  'Couture': 108,
#  'Zines': 144,
#  'Photobooks': 608,
#  'Places': 283,
#  'Space Exploration': 137,
#  'Radio & Podcasts': 349,
#  'Textiles': 105,
#  'Chiptune': 10,
#  'Plays': 539,
#  'Farms': 482,
#  'Small Batch': 701,
#  'Illustration': 1263,
#  'Rock': 2707,
#  'Pet Fashion': 51,
#  'Video Art': 65,
#  'Classical Music': 1064,
#  'Embroidery': 49,
#  'Young Adult': 328,
#  'Events': 322,
#  'Pop': 1302,
#  'Art': 3358,
#  'Faith': 439,
#  'Accessories': 1204,
#  'Apps': 2535,
#  'Product Design': 8886,
#  'Webcomics': 259,
#  'Apparel': 2827,
#  'Fashion': 3379,
#  'Experimental': 357,
#  'People': 440,
#  'Music': 6229,
#  'Drama': 871,
#  'Literary Journals': 118,
#  'Hardware': 1431,
#  'Translations': 76,
#  'Games': 1331,
#  'Printing': 83,
#  '3D Printing': 271,
#  'Narrative Film': 2099,
#  'Food': 4612,
#  'Literary Spaces': 10,
#  'Country & Folk': 1790,
#  'Television': 401,
#  'Blues': 113,
#  'Musical': 367,
#  'Jewelry': 472,
#  'Candles': 168,
#  'Food Trucks': 687,
#  'Nature': 219,
#  'Web': 2017,
#  'Romance': 74,
#  'Dance': 901,
#  'R&B': 172,
#  'Workshops': 59,
#  'Immersive': 131,
#  'Bacon': 78,
#  'Graphic Design': 765,
#  'Shorts': 4857,
#  'Gaming Hardware': 178,
#  'Thrillers': 302,
#  'Performance Art': 855,
#  'Jazz': 733,
#  'Punk': 127,
#  'Quilts': 32,
#  'DIY Electronics': 358,
#  'Animation': 1017,
#  'Community Gardens': 115,
#  'Robots': 237,
#  'Public Art': 1248,
#  'Documentary': 6498,
#  'Photo': 58,
#  'Glass': 51,
#  'Taxidermy': 7,
#  'Ceramics': 128,
#  'Comic Books': 1032}

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Compter le nombre de projets français ayant été instanciés avant 2016.

# %%
# country : FR
# launched : <2016.01.01
import datetime

before = datetime.datetime(2016, 1, 1)
cursor = collection_kickstarter.find({"country":"FR", "launched":{"$lt":before}})

len(list(cursor))
# Out:
# 330

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Récupérer les projets américains ayant demandé plus de 200 000 dollars.

# %%
# country : US
# goal : >200000

cursor = collection_kickstarter.find({"country":"US", "goal":{"$gt":200000}})

{e["name"]:e["goal"] for e in cursor}
# Out:
# {'A CALL TO ADVENTURE': 287000.0,
#  'Storybricks, the storytelling online RPG': 250000.0,
#  'Shine On New World': 300000.0,
#  'Nightclub': 3000000.0,
#  'Nastaran (Wild Rose)': 250000.0,
#  'Hubo - Extension Box for iPhone': 250000.0,
#  'Baja ATV Park (Suspended)': 300000.0,
#  'Chihuly Installation for Orlando (Pulse Nightclub)': 1000000.0,
#  'Kurt Vonnegut: Unstuck in Time': 250000.0,
#  'The LAKE HOPPER is a VTOL Flying Water Craft Made in America': 3000000.0,
#  '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)': 1000000.0,
#  'Saints of The Classroom': 250000.0,
#  'Hemingwrite - A Distraction Free Digital Typewriter': 250000.0,
#  'Breakfast 24/7': 1000000.0,
#  'FJE REVOLT': 500000.0,
#  'Austin City Limits 40 Year History Documentary Film': 400000.0,
#  'Ozark Mountain Ranch': 466000.0,
#  'STEM Lesson Plan - BotBrainï¿½ Educational Products': 279646.0,
#  'Guitar Godz VR: A 3D Rock Music Game': 500000.0,
#  "The world's first crowd funded millionaire documentary": 1000000.0,
#  'Creating an online game, "Perdition Online".': 350000.0,
#  'The Adventures of Billy Buskirk': 750000.0,
#  'MY TINSEL TOWN (Canceled)': 577000.0,
#  'Moonlight 5 star (Canceled)': 250000.0,
#  'Dangerous Seas: A Beautiful Under Water War App (Canceled)': 400000.0,
#  'ViewCoze.com | Cozy viewing from home (Canceled)': 370000.0,
#  'Meet kubo: an electric scooter to carry all your stuff!': 300000.0,
#  'ONEIDNET Social Professional Commercial Corporate Platform': 545539.0,
#  'The Scariest Movie Ever Created': 100000000.0,
#  'The SEED Project': 250000.0,
#  'NewsRadio Season 6 (Canceled)': 3000000.0,
#  'Get Me Me Kids (Books, Music, Film & Games)': 500000.0,
#  "Daniel's Dream": 2000000.0,
#  'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc': 444000.0,
#  'GolferVox': 1200000.0,
#  'Power Rangers | fan film reboot movie': 400000.0,
#  '"Another Network" Film Project': 225000.0,
#  'SELF-SUSTAINING ORGANIC FARM': 450000.0,
#  'Fuel-X-Tender': 500000.0,
#  'Salad Barr ( the new fast food restaurant )': 270000.0,
#  'We want your money (Suspended)': 300000.0,
#  "Dutch's Kegs": 1000000.0,
#  'Pro Tailgater Party Plate': 365000.0,
#  'Gabriel Device - Free energy for everyone': 500000.0,
#  'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!': 875000.0,
#  'Fast Easy Lightweight Modular Cabinets PhastPhurniture': 250000.0,
#  'Sonic Chao World fan game (Canceled)': 1000000.0,
#  'The Darkest Dawn': 500000.0,
#  'Adventure Combat Ops - A real life, apocalyptic video game!': 400000.0,
#  "World's First Smart Football": 500000.0,
#  'The Maryanne Godboldo Story (Canceled)': 250000.0,
#  'M.A.C.S. (Canceled)': 400000.0,
#  'Planetary Annihilation - A Next Generation RTS': 900000.0,
#  "Pontruff's Pop Shop, Pizza, and Punk Rock": 500000.0,
#  'The Good Fight of Faith': 1000000.0,
#  'Film Adaptation of "The Traveler"': 1000000.0,
#  'Uncommon Wealth': 250000.0,
#  'Design the Starship Enterprise Science Research Mock Up': 313550.0,
#  'Backyard Soccer Buddy / Football Mate (Overseas)': 2000000.0,
#  '"anonymous (street meat)" (Canceled)': 1000000.0,
#  'Hello Space Boy!': 2000000.0,
#  'Interactive Breastfeeding Documentary': 210000.0,
#  'Aquaponics system for supplying fresh organic food.': 8000000.0,
#  'After Reset RPG': 900000.0,
#  'SLAYING GIANTS #GOLIATH': 350000.0,
#  'Fan News': 275000.0,
#  '*FLASHLIFE* Most Complete Emergency Survival Product Ever.': 350000.0,
#  "Iota: Never lose sight of what's important.": 250000.0,
#  'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY': 2000000.0,
#  'jfg76tukv u': 250000.0,
#  'Shaft in Asia Featured Film': 1000000.0,
#  'P.U.R.E. Gamers': 500000.0,
#  'The Hawaiian Girl Art Studio (Canceled)': 1100000.0,
#  'Independent Broadcasting Company': 700000.0,
#  'Forbidden Woods (Canceled)': 2300000.0,
#  'The Guilt Free Life': 250000.0,
#  'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca': 780000.0,
#  'Puzzle Camp': 750000.0,
#  'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo': 500000.0,
#  "THE YING YANG MURDER MYSTERY'S (Canceled)": 900000.0,
#  'Montgomery Al Concert 5FDP and VOLBEAT': 1040000.0,
#  'Wall Scaler': 1000000.0,
#  'Historic B&B with an in-house French Bakery in Memphis, TN': 250000.0,
#  'Angelz Landing the Movie': 1200000.0,
#  'Morrison Land': 250000.0,
#  'Triple Espresso Goes to The Big Apple': 300000.0,
#  'Take And Seek the Movie': 250000.0,
#  'Unsung Story: Tale of the Guardians': 600000.0,
#  'Harishwar Center for Arts, Spirituality & Sustainability': 1800000.0,
#  "The Cancer Patient's Film Project": 1500000.0,
#  "Small Change: Kids' Financial Life Skills": 250000.0,
#  'Save the Williamsburg': 40000000.0,
#  'Nephilim, Nazis and the New World Order': 500000.0,
#  'War At Home': 340000.0,
#  'North East': 250000.0,
#  'The Great Pyramid, Project USA': 300000.0,
#  'Time travel app': 375000.0,
#  'Honolulu Haze (Canceled)': 500000.0,
#  'Motor Sports Mailboxes': 600000.0,
#  'Patented MoveNetic Lock - New Post 9-11 Locking Method': 350000.0,
#  'Hoverboard: The Next Evolution in Personal Electric Mobility': 500000.0,
#  'Make A South African Feature Film! (Canceled)': 2500000.0,
#  'Feature-Length Movie: Secret of the Missing Grave': 10000000.0,
#  "Hey Chicago  It's all about you!": 380000.0,
#  'All Points Bulletin (APB): Vendetta': 300000.0,
#  'As Cine On TV': 2000000.0,
#  'The Hendrix Keg - Carbonated, Fresh, Craft Beer on Tap': 300000.0,
#  'Love Gives Hope Art Gallery for Cultural Diversity!': 300000.0,
#  'The "Get Home Now" Device': 250000.0,
#  'In Pursuit of Passion - Travel Television Series': 280000.0,
#  'Welcome to the Wonderful World of AIDS': 500000.0,
#  'The Homeless art Studio (pic from AP) FUCKING HELP OUT': 500000.0,
#  'From Dawson to Jackson Vineyards': 1000000.0,
#  'Art Story': 350000.0,
#  'My a MAZING Academic Profile': 2852666.0,
#  'The Hill (Canceled)': 1575000.0,
#  'Sports Cards Unlimited (Canceled)': 400000.0,
#  'Pushup Extreme. (Canceled)': 215000.0,
#  'Everyday Dreamers Living in the Beautiful Struggle': 3500000.0,
#  'Top Side Dinner Show! Eat, watch, party, and always enjoy!': 425000.0,
#  'The Real Kratos - Epic Action Film': 295000.0,
#  'My Russian Kitchen: Love Story': 495000.0,
#  'The Fuffr Touch Case ï¿½ Multitouch Outside Your Smartphone': 250000.0,
#  "Joe N'Mo To Go!": 400000.0,
#  'Japanese Fighting Fish & Japanese Fighting Fish Hold Em': 500000.0,
#  'Samurai Lone Wolf': 300000.0,
#  'Today.Feats.Us = The Human Fund': 375000.0,
#  'This is my dream (Este es mi sue?o)': 1000000.0,
#  'Bay Area Snow Park': 1000000.0,
#  'A Self-Sufficient Sober Living Farm': 600000.0,
#  'ONE DEGREE, a productive social network': 1000000.0,
#  'Art and jewelry made with Silvondï¿½ - Beyond Silver...': 201349.0,
#  'Save the Circus': 325000.0,
#  'Happy Happy, Joy Joy - The Ren and Stimpy Story': 289400.0,
#  'The God MC': 5000000.0,
#  'Soaring Beyond - A 90 Day Empowering Life Transformation': 250000.0,
#  'Ninja Warz': 285000.0,
#  'MOST. BLOOD. EVER.': 250000.0,
#  "A GOOD MAN'S DECISION": 500000.0,
#  'Happy REX( Kids Book Collection) (Canceled)': 300000.0,
#  'Hooked on a rail': 400000.0,
#  'The Fantom Messenger': 500000.0,
#  'Trump Redux: Help us tell the real story about Donald Trump.': 250000.0,
#  'AIRBLADE:  Extreme Hockey': 700000.0,
#  'Superior Motors: Community Restaurant & Farm Ecosystem': 250000.0,
#  'Hey Moe! Hey Dad!': 350000.0,
#  'Air Dash Online  - A Competitive Platform Fighter (Canceled)': 355555.0,
#  'Get Em Up': 1000000.0,
#  "EDM 2015 Dj's United": 700000.0,
#  "Moreno's Art (Canceled)": 500000.0,
#  'DEADSKINS (Canceled)': 365000.0,
#  'Little Magdeline (Film)': 400000.0,
#  'INSIDEOUT (Canceled)': 1250000.0,
#  'Remix IO - A 4K, Nougat-powered, All-in-One device': 250000.0,
#  'KaliPAK is a portable, renewable energy generator': 250000.0,
#  'Chips Challenge Ultimate 3D': 300000.0,
#  'STD-Verify: An online STD verification website.': 500000.0,
#  "John Knight's Operation: Project A.L.B.A (Canceled)": 225000.0,
#  'Throwing an art event In Petersburg VA': 313400.0,
#  'Designed snare drum heads (Canceled)': 1000000.0,
#  'St Patrick of Ireland biography film project': 1875000.0,
#  'The Magical Mystery Show featuring The Last Great Wizard': 685000.0,
#  'Ariel Sky - The Future of Healthcare': 250000.0,
#  'Project DaVinci - Get Access to Space': 250000.0,
#  'The Untitled Highly Inappropriate Project': 300000.0,
#  'Equestrian Complex & Western Museum (Canceled)': 300000.0,
#  'WOW Education Rewards - Furry Witty Edufeed Reward': 250000.0,
#  'Jog the Dog: Indoor Track and Dog Exercise Field': 500000.0,
#  'The new "Best Restaurant" Academy in town.': 500000.0,
#  'Flat Creek Agri-Tourism and Outdoor Family Gaming': 16610000.0,
#  'The Man Who Got Carter': 207000.0,
#  'Supreme Life Foods': 1000000.0,
#  'King James Version Bible comic book': 350000.0,
#  'From Ashes': 2500000.0,
#  'Crowfall - Throne War PC MMO': 800000.0,
#  'Modern Artistic Retreat': 300000.0,
#  'DNA: Code Flesh (Book One: Dead Nations Army Duology)': 250000.0,
#  'Have Steam Engine, Will Travel': 500000.0,
#  'I H8 Math: A Pre-Algebra Guide': 1000000.0,
#  'AppEater - Your Mobile desktop will never be safe again!': 350000.0,
#  'Fort Miami Games Mobilize!': 225000.0,
#  'Music Has Legs movie': 250000.0,
#  'Dr. Mï¿½s Universeï¿½ featuring Jerry Lucas, a.k.a. Dr. Memoryï¿½': 350000.0,
#  'Sydewynder Wheels': 500000.0,
#  'The Time Jumper': 100000000.0,
#  'The Pizza Truck': 225000.0,
#  'LASTER SeeThru': 300000.0,
#  'Organic, tasty Shrimps from Northern Germany into the world': 250000.0,
#  'Robotic Handling System': 998000.0,
#  'Birth of Man - A Minecraft Feature Film (Canceled)': 600000.0,
#  'CODE OF DEATH (Canceled)': 350000.0,
#  'Drive with Lynk': 750000.0,
#  'Messages to Heaven': 500000.0,
#  '"Foam" - Reality TV Show for 2015': 2500000.0,
#  'Hydroponics: Stop World Hunger': 300000.0,
#  'Donald Trump Saves The World': 210000.0,
#  'One Ugly Baby': 3300000.0,
#  'Jayhawk Racing Bikes': 250000.0,
#  'Zafirro. Sapphire Blade Razor.': 1000000.0,
#  'Mobile Space Camp (Canceled)': 900000.0,
#  'Colorvision Films': 5000000.0,
#  'Tradewinds Terrace. INC': 9592440.0,
#  'World of Kingdoms ~ New MMORPG': 700000.0,
#  'Get 100,000 Copies Of My Neighborhood Book To Children': 1500000.0,
#  'Day Maker : the Charging iPhone Alarm Toaster': 275000.0,
#  'Chucky:  Wanna Play? (Canceled)': 925000.0,
#  'Percussion Archive': 250000.0,
#  'CineBlock the gaming spot (Canceled)': 550000.0,
#  'Invergo: An Automated Pour Over Coffee System': 250000.0,
#  'PySchool.net - Advancing Python in the Classroom': 2000000.0,
#  'Ghetto America': 500000.0,
#  "Mr. Rick's Trading Post": 2000000.0,
#  'ANIMAL HOUSE: a series for people who LOVE animals!': 600000.0,
#  'MegaCafe Gaming and coffee 24/7': 800000.0,
#  'Full feature film: Alfredo': 400000.0,
#  'Refugee Socks': 5017511.0,
#  'Music, Magic, Energy and GOD': 650000.0,
#  'Twilight Nation': 300000.0,
#  'Top secret recipes that we all need to know.': 2300000.0,
#  'Photo Caffe': 500000.0,
#  'SKYDANCE': 500000.0,
#  'Skyteboard 3G Quadcopter with Fatdoor Social Network Connect': 300000.0,
#  'Velvet Blu Mediterranean Restaurant': 350000.0,
#  'Experiencing the Divine Comedy': 300000.0,
#  'Building A Film Production': 5000000.0,
#  'Comedy Spoof Yucca Man movie (Canceled)': 300000.0,
#  'Home is Where I Die... (Canceled)': 500000.0,
#  'Spoils of War (TM)': 350000.0,
#  'Abduction alert bracelets': 250000.0,
#  'ENERGY FLOW NETWORK:  24/HR Platform for Everything Energy': 500000.0,
#  'Forge': 300000.0,
#  'Dancing Dragon': 250000.0,
#  "'Street God'": 400000.0,
#  'Gouddaa series (Canceled)': 40000000.0,
#  'Transgender Documentary on TLC "My Transgender Life"': 600000.0,
#  'BioMight - The Might of Biological Animations': 220000.0,
#  'Z-Magics: Magic Exposed': 250000.0,
#  'Ninja Zombies! (Canceled)': 315000.0,
#  'Organic Dates and Papaya New Plantation': 800000.0,
#  'Dark Meridian': 250000.0,
#  'Operation Rock Bottom - The Power of Wall St. on Your St': 250000.0,
#  'Not only a Bluetooth Amplifier. Its so much more and compact': 300000.0,
#  'Transform the Wedding Cake House Into the Providence Inn': 500000.0,
#  'Portraits of War': 635000.0,
#  'Kllabo - Inventing gone viral': 537600.0,
#  'ZICAM: THE UNTOLD STORY': 250000.0,
#  'Forgotten F-105 Warriors of Operation Rolling Thunder': 293000.0,
#  'The Greatest Escape (Canceled)': 2000000.0,
#  'TEST (Canceled)': 1000001.0,
#  'A Veterans FIVE Year Mission!!!': 425000.0,
#  "Club Toke'n Token's: Video Arcade & Smoke Lounge (Canceled)": 1000000.0,
#  "World's First Custom Fit Sandals, 3D Printed in USA": 250000.0,
#  'Citana: Animation Streaming': 300000.0,
#  'Litigram: Personal Holograms in Full-Color 3D': 215000.0,
#  'Ride Share Revolution (Canceled)': 500000.0,
#  'Fitness App that does it all. Kilojoules': 250000.0,
#  '3D Printed windsurf, kite, surf, and paddle SmartBoardsï¿½': 450000.0,
#  'Asynchronicity Shell': 1000000.0,
#  "The Making of 'Picture Perfect?' (Canceled)": 500000.0,
#  'New Superhero MMO (Among Us) (Canceled)': 5000000.0,
#  'Aladdin Lucid Dreaming Stimulator': 250000.0,
#  'SousVide Supreme Touch+': 250000.0,
#  '"Songs from the 21st century"  - new rock 4 a new world': 300000.0,
#  'The Visual Bible Experience - Watch The Bible Come To Life!': 250000.0,
#  'HelSTAR: The Wireless Helmet Brake & Signal Light': 250000.0,
#  "Mist' R Bucket (Canceled)": 250000.0,
#  "LEARN: Tags - The Most Innovative Graffiti Game You'll Play": 212585.0,
#  'The Scott Emo Show - New Talk Show Inspired To Change Lives': 500000.0,
#  'COEXISTENCE the Movie (Canceled)': 1750000.0,
#  'The Throne : Fall of Lucifer': 100000000.0,
#  'Art, Music & Food Incorporated': 415900.0,
#  'Dragon Bones: the Future of Electronic Fun (Canceled)': 1625000.0,
#  'Phoenix Rising': 1000000.0,
#  'Second Sunrise Movie Project': 350000.0,
#  'my animated series (Canceled)': 500000.0,
#  'DIG COMICS': 250000.0,
#  'The Dick Jones Feature Film Project': 250000.0,
#  'Michigan Fusion Corporation': 1000000.0,
#  'Xeko': 250000.0,
#  'Meeting Mapper': 250000.0,
#  'College Football Championship Game (Canceled)': 1000000.0,
#  'The Game Room': 250000.0,
#  'The Food of My People': 300000.0,
#  'The Baby': 2500000.0,
#  'Judged At First Sight': 500000.0,
#  'Pushed.': 600000.0,
#  'The Original Good Times Cast Movie': 1000000.0,
#  'Between The Bars - Elliott Smith': 685000.0,
#  'Z-Style Concept Arm': 240000.0,
#  'Family Entertainment Center, Rankin County MS': 500000.0,
#  'fixl': 350000.0,
#  'Heavy Gear Assault (Canceled)': 800000.0,
#  'Project: Nourish': 3500000.0,
#  'SUBJECTIVE': 800000.0,
#  'Auraspark': 900000.0,
#  'Slickview': 529000.0,
#  'The Spin Wrench Worlds First Stress Free Tool! (Canceled)': 250000.0,
#  'Dead Drunk (Canceled)': 1500000.0,
#  'Build Your Own Laser Cutter': 300000.0,
#  'Archon-01 Initiation': 1125789.0,
#  'The Fascination': 780000.0,
#  'Once Upon A Time In Shaolin - For Wu Fans, For Wu People': 5000000.0,
#  'The Cyanide & Happiness Show': 250000.0,
#  'Asbury Park, USA': 500000.0,
#  'Slot Car Mania!!!': 500000.0,
#  'Kurt Vonnegut Museum in his Childhood Home': 800000.0,
#  'Animated Short Series- Spookiz': 300000.0,
#  'Warehouse 34 (Canceled)': 300000.0,
#  'Lit Savage Wrestling': 250000.0,
#  'WUNDERKINDZ: The Musical Summit': 300000.0,
#  'StarDrive Propulsion (Canceled)': 350000.0,
#  'Reality Gaming (Canceled)': 485000.0,
#  'SideJobs (Canceled)': 1000000.0,
#  'WhosRunningAnyway': 305000.0,
#  'Radical, Revolutionary, Rutan. Now fly your own SpaceShipOne': 220000.0,
#  '"The Irwins" : Animated Series': 500000.0,
#  'My Mission (Canceled)': 5000000.0,
#  'CyrcleDIY: Reinvent Your Internet Experience (Canceled)': 220000.0,
#  'Zippy Pop! The Ultimate Stove top Snack Maker!': 250000.0,
#  'Fidelis Cloud (Canceled)': 1500000.0,
#  'CasaPlutonia Retreat: The Journey of Mind, Body, and Soul': 250000.0,
#  'The Crime Busters (Canceled)': 840000.0,
#  'Purchase B.o.B A Ticket To Space On A Virgin Galactic Flight': 250000.0,
#  '50/365: America 2014': 1000000.0,
#  'gaincontrol/guncontrol': 225000.0,
#  '"Arab Money" The Movie plus a Sound Track (Canceled)': 400000.0,
#  'La Casa de Vida Wellness Center': 600000.0,
#  'The Launch Jacket': 250000.0,
#  'Gemini - The Album that Changed The World (Canceled)': 340320.0,
#  '"BERN" ï¿½ The Bernie Sanders Documentary (Canceled)': 448129.0,
#  'Days End Feature Film': 500000.0,
#  'SHIELDS Empowering Consumer Health and Protection': 1600000.0,
#  'illo - birth of the cool (Canceled)': 270000.0,
#  'Sprayview Campground: A Sustainable Rockaway Community': 400000.0,
#  'Project Patriotic Eats: Food Channel & Food Truck . GO USA!!': 250000.0,
#  'Trials of Ascension (Canceled)': 600000.0,
#  'The Rajin Krajian-Shuttle Driver': 220000.0,
#  'FLOW: Life Unplugged-High Definition Bluetooth +APTX Adapter': 250000.0,
#  'Pollution Fighting, with Lawnmower Lighting! Cooler Mowing.': 250000.0,
#  'Nostalgia Arcade': 525000.0,
#  'Beautify our Highways': 250000.0,
#  "Flynn's Pizza": 250000.0,
#  'DANCE, DANCE - Guinness World Record Dance Event': 900000.0,
#  '"8 Songs" Documentary - Did music shape human evolution?': 240000.0,
#  'Janus World Summit & Festival: recognizing talent worldwide': 265000.0,
#  'Vluxe: Fashion Like No Other On Earth.': 300000.0,
#  'Me2': 4000000.0,
#  'Sky Bridge: Fallen Stars': 250000.0,
#  'Swimming With Guppies': 260000.0,
#  'Grown Folk': 498129.55,
#  'MaxMyTV: Home Automation and Social Media Overlay on your TV': 250000.0,
#  'THE SESSIONS - The Beatles at Abbey Road Studios (Canceled)': 375000.0,
#  'Casetop - Every Phone Becomes a Laptop': 300000.0,
#  '"Madam Mississippi"': 250000.0,
#  'How to use your voice powerfully & everyday, made easy!': 400000.0,
#  'Need a Ride?': 750000.0,
#  'VR Extreme': 500000.0,
#  'KHWIKBALL (Canceled)': 300000.0,
#  'American Pick Inc.': 800000.0,
#  'Black Arts Matter': 550000.0,
#  'Katun': 350000.0,
#  'BalletCon': 700000.0,
#  '/r/frontpagefilms': 250000.0,
#  'I-Tem brand Wine Dispenser': 600000.0,
#  'Minis with Enemies, taking tabletop mini gaming digital!': 300000.0,
#  'The Den Alternative Center': 250000.0,
#  'Pico C - Craft Brewing For All': 350000.0,
#  '9 11 Responders Honored by Statue "The Ascension of Heroes"': 3730000.0,
#  'Good Grief, Zombies': 450000.0,
#  'DJBennett.com The World of SPORTING LUXURY': 500000.0,
#  'Copy2': 250000.0,
#  'Picanonymous Mobile Second Edition': 285000.0,
#  'PlayToLearn.com': 350000.0,
#  'THE GREAT CANADIAN TAR SANDS SWINDLE': 260000.0,
#  'Literary Animated Mobile Book Application': 300000.0,
#  "Global Coin Exchange you'll be glad you did!!! (Canceled)": 500000.0,
#  'Galaxy Shed - Astronomy for everyone.': 209731.0,
#  'Feature Film - Friendly Ghosts - James Dean': 400000.0,
#  '"Secrets"': 1000000.0,
#  'To The Death': 400000.0,
#  'Help erase the national debt of the USA': 21474836.47,
#  'Gouddaa Sons Of Titan': 2000000.0,
#  'LEGEND OF A HITMAN (Canceled)': 250000.0,
#  'Winged Warriors the Movie': 462500.0,
#  'Lamp | The Ultimate Adjustable Stand+Dock+LED Light': 270000.0,
#  'Intelligent Design: The Series': 33000000.0,
#  'The Poopy Pals First Adventure': 250000.0,
#  'City of Rain (Canceled)': 500000.0,
#  'Space Exploration Drone Vehicle': 2000000.0,
#  'Gluten Free Fabulous': 1500000.0,
#  'Southern Boys Country Cooking': 475000.0,
#  'Sonic Entertainment Corp': 900000.0,
#  'My little Big Data - Your 1st True Personal Home Server': 250000.0,
#  'Villa Majutiwil, Dream Place to Live and Retire': 700000.0,
#  'Bronze twin-sculpture of Nelson and Zenani (ggd) Mandela': 1000000.0,
#  'Although I Deserve To Die Movie Production': 2875000.0,
#  "TANKY: World's Fastest Production Drone": 225000.0,
#  'Juntos - Our Unsocial Identity': 580000.0,
#  'The Phone for Humans': 500000.0,
#  'THE PRIZE GUYS - a coming-of-age comedy drama feature film': 987000.0,
#  'Orion OGS: Affordable 3-in-1 Computer, Media & Gaming System': 500000.0,
#  'Fires of Strife': 1000000.0,
#  '20th Century @ War (Canceled)': 1745000.0,
#  'UPCYCREATION for a Clearer Future': 250000.0,
#  'LITTLE ROCKERS': 300000.0,
#  'FAITHFUL NEIGHBORS': 201700.0,
#  'Saving Capitalism - Starring Robert Reich': 256500.0,
#  'Outpost One': 205000.0,
#  'Real Block - The first 3D Social Game on Facebook!': 450000.0,
#  "Aberford: A video game of zombies and 50's housewives": 675000.0,
#  'SURVIVING TRUMP Diverse People Making America Great Everyday': 300000.0,
#  'Dino Land - A Jungle Park Filled with Dinosaurs!': 4000000.0,
#  'project:13 - a music driven animation trilogy': 390000.0,
#  'Grim Dawn': 280000.0,
#  'Paintball Colosseum': 550000.0,
#  "Ben's Astrophotography Studio and obsovatory": 285000.0,
#  'Ride - Your Personal Driver': 500000.0,
#  'Spokane Drive In Theater': 500000.0,
#  'Yolotag - Live it, Prove it. Get credit for your adventure!!': 825000.0,
#  'Farming the better red meat': 300000.0,
#  'Life Online': 300000.0,
#  "Tbone's Billiards & Grill": 300000.0,
#  'MowBuddy': 250000.0,
#  'Herbal Sex Tea': 500000.0,
#  'The Luscious Palace': 250000.0,
#  "Cats! Cafe! Let's Bring a Purrfect Combination to LA!": 350000.0,
#  'Time Lapse U.S.': 247000.0,
#  'The Adventures of Brent & Ben! Season 1, 2, & 3 Kickstarter': 700000.0,
#  'inPatient Help, Acuity & Communication Tablet System iPHACTS': 497900.0,
#  'Eclessia Ascending': 500000.0,
#  'The American Big Pharma Film': 350000.0,
#  'Turtle Rocket Books': 1000000.0,
#  'Voltara Battle for the Galaxy': 500000.0,
#  'Shadow Black Gaming & Community Center (Canceled)': 300000.0,
#  'The Outdoor Kid': 350000.0,
#  'QUICK STANCE': 1000000.0,
#  'Recrudescence Online (Canceled)': 350000.0,
#  'Clean Tech for the Protection of Public Health & Environment': 280000.0,
#  'iTworx': 250000.0,
#  'ThumbDancer': 300000.0,
#  '"The Warrens Wraith"': 1000000.0,
#  'WETGEAR "RIPFLIP" The World\'s First Walkable Flipper!': 250000.0,
#  '"Swoooosh"': 2000000.0,
#  'Wish-Li.com: Give and receive the perfect gift, every time!': 500000.0,
#  'Monitor,TV,SolarPanel,Slat adjustable cart/dolly': 3300000.0,
#  'Magic SQL .NET': 2500000.0,
#  'Bakery/Cafe': 250000.0,
#  'The Bucket Booster!': 250000.0,
#  'Gocycle - the BEST folding electric bike in the world!': 250000.0,
#  'Talk Is Cheap -  from Academy Award Winner Barrie M. Osborne': 1500000.0,
#  'Regenerate': 10000000.0,
#  'Lightpack ï¿½ ambient backlight for your displays': 261962.0,
#  'Not My Flag': 500000.0,
#  'Karmic Kyoto': 249000.0,
#  'MindStream Aquarium Monitor': 300000.0,
#  'Social Media Impact of Student Violence': 350000.0,
#  'hopps | patrons order drinks, venues drive revenue': 350000.0,
#  'Drone Controls': 215000.0,
#  'Bee Barrels: The 21st Century Beehive!': 300000.0,
#  'No More Heroes:The movie': 500000.0,
#  'Introducing the Airdog ADII: The Future is Hands-Free': 250000.0,
#  'The Best Kickstarter Video Ever': 73000000.0,
#  'For All The Tea In China': 500000.0,
#  'Oculus Maximus (Canceled)': 225000.0,
#  'Virtual Reality - Duck Hunter': 500000.0,
#  'Umdlalo (Canceled)': 575000.0,
#  'Revolutionary Music, Arts & Technology Festival (w/ Book)': 250000.0,
#  'Ghostbusters: The Board Game II': 250000.0,
#  'House Rules I': 201000.0,
#  '" Radio Reunion " - The Movie. (Canceled)': 1000000.0,
#  'W.A.S.T.E TeleVision Innovative Online Broadcasting Platform': 917000.0,
#  'Crankers, Tweeners & Strokers (Canceled)': 325000.0,
#  'Mega Music Artist PlayApps': 750000.0,
#  'New Sports Industry': 700000.0,
#  'Ryan\'s art studio $1 for printable 16"/20"': 300000.0,
#  'ParaShoot - Smart HD Videography Everyone Can Wear': 260000.0,
#  "Harambe's Revenge": 1500000.0,
#  'Sons & Daughters of Africa Awards [Global Broadcast]': 499999.0,
#  'Miracle Mouse-Cranky\'s Miracle, 2D "Throw-Back" Feature Film': 250000.0,
#  "Kitty's Secret Activities Memoir": 1000000.0,
#  'Offer & Compromise': 500000.0,
#  'PARTYGRAM': 250000.0,
#  'OFA Opening Night': 300000.0,
#  'The Blur': 300000.0,
#  'Mega Project: A FUTURE Without Chemicals and Healthy Food.': 250000.0,
#  'CHRONOLOGY': 350000.0,
#  'The Read Read: Braille Literacy Tool for the Blind': 273000.0,
#  '5k Truffles Orchard - Adopt A Tree Today.': 880000.0,
#  'INFLUENCERS ACADEMY 2016': 225000.0,
#  "Tony La Russa's Baseball with Fans": 249000.0,
#  'The Cultivator Episode 1 Lord Of The Gorgs': 50000000.0,
#  'The Nut Hut': 305365.0,
#  'sss (Canceled)': 275000.0,
#  'MICHIGAN - HIGH CALIBER SCIENCE FICTION': 1000000.0,
#  'Got Worms? - Vermicomposting in Arizona': 298500.0,
#  'MindGear - Mind Control for Your iPhone or Android Phone': 250000.0,
#  'HELLO AMERICA THE WORLD IS WATCHING': 1150000.0,
#  'Pray For Dark (Canceled)': 400000.0,
#  'Hairbands, Pilot Episode': 325000.0,
#  'Panacea2': 535000.0,
#  'Book Bros.': 3000000.0,
#  'a really cool Super Cybermobile!': 1200000.0,
#  'RED ASH - The Indelible Legend': 800000.0,
#  'A true look into Islam and The United States of America': 700000.0,
#  'The scariest movie ever': 1000000.0,
#  'Core Activation Training System for Better Physical Movement': 250000.0,
#  'HeartForCancer.com': 550000.0,
#  'ComiCosplay Cafe': 450000.0,
#  'Smoking Barrel by Christopher Harmason for (PC,Web Browsers)': 295500.0,
#  '"SUDS COUNTY 2: The Boil Over" A San Diego Beer Documentary': 250000.0,
#  'Crooked City': 249000.0,
#  'high school football focus': 250000.0,
#  'The Undersea Aviary': 250000.0,
#  "Bogart Bay Shrimp - Missouri's First Salt Water Shrimp Farm": 250000.0,
#  'Breakfast Drone-Delivery System': 700000.0,
#  '5 on Monday (Canceled)': 300000.0,
#  'Canopus Weekplanner watch launch A.Manzoni & Fils': 500000.0,
#  'Vanishing Culture (Canceled)': 250000.0,
#  "Washington's first ethical Erotic dance club": 2000000.0,
#  'Ossus Online: The Rise of Virtue (Canceled)': 900000.0,
#  'A Dove of Peace wants to get hatched!': 275000.0,
#  'RANCH GIRLS': 350000.0,
#  'Color Pixel - Paint By Number (Build a #1 Ranked App)': 500000.0,
#  'Qubi: The Media Center Reinvented': 500000.0,
#  'Protection bag to carry equipment with lithium batteries.': 350000.0,
#  'SLAPSHOT HOCKEY': 750000.0,
#  'ChaZING! Smart Facebook Shops': 300000.0,
#  '2 Brothers Woodfired Deli and Pizzeria': 250000.0,
#  'Sinners Holiday': 333000.0,
#  'YogaMeDo - Nutrition and Mental Health Education for Schools': 250000.0,
#  'Break Barriers and Versus Series': 300000.0,
#  'Crazy Shades of Blue': 350000.0,
#  'Pathologic (???.??????)': 250000.0,
#  'Trials of Ascension: A truly innovative MMORPG (Canceled)': 750000.0,
#  'Ionobell - Green, Sustainable Batteries': 500000.0,
#  'Print-a-Part3d.com': 250000.0,
#  "Fund and support on Keyon Brown's Hip Hop and Rap Career": 500000.0,
#  'STEM System: The Best Way to Interact with Virtual Worlds': 250000.0,
#  'Never Forgotten Project': 350000.0,
#  'VET Tv - Streaming TV network for post 9/11 veterans': 250000.0,
#  'CATHARSIS / Liliana Martin Movie (Canceled)': 220000.0,
#  'Chronicles - History by us, as we tell it, as we share it': 250000.0,
#  'Fragmented Reality: New Technology and World Defense (Game)': 385000.0,
#  'Kicked Out!': 300000.0,
#  'Fast eddies spaghetti.  100% organic': 695000.0,
#  'Wheeliesï¿½ Revolutionary Display For Your Motorcycle': 250000.0,
#  '"Programming in Pearls" Monument by Sabra Tull Meyer': 385000.0,
#  'CIRCLE OF DOORS Major Motion Picture Development': 700000.0,
#  'aid path (Canceled)': 300000.0,
#  'Shadowrun Online': 500000.0,
#  "Niwot's Curse": 1500000.0,
#  'GreenResolve Home Energy Monitor': 250000.0,
#  'The Holy Will is a Christian Ministry:': 1000000.0,
#  'Can You SCRUMMY?!!!': 500000.0,
#  "I don't know a comic book?": 10000000.0,
#  'The Puppet Show: Season 2': 400000.0,
#  'LLORONA THE LEGEND (Canceled)': 1870000.0,
#  'The Chivalrous Society on the Cutting Edge of Normal ï¿½?': 250000.0,
#  'Back the Booster': 500000.0,
#  'Snowyville (Canceled)': 900000.0,
#  'Blueprint (Canceled)': 550000.0,
#  'TickerPix App (Fund for future updates)': 1000000.0,
#  'Project Arcane': 400000.0,
#  'USB Digital Shoe': 500000.0,
#  'Descon 8 Standard - Structural Engineering Software': 600000.0,
#  'The longest man-haul journey in history.': 300000.0,
#  'Burlington Waterworks: Banquet, Museum and Community Center': 264698.0,
#  'CREATURES OF THE NIGHT (Canceled)': 300000.0,
#  'STAR WARS -A Game the Fans Want- (Suspended)': 500000.0,
#  'Crescent Moon Spirits': 550000.0,
#  'SIGNOOS - Free EDU Series for Deaf Schools around the world.': 685500.0,
#  'Crayfish Sports Bar': 795000.0,
#  'CRE81 RIDESHARE APP': 350000.0,
#  'Hannah Z. - Creating the Art of True Fashion': 215000.0,
#  "Artist's Table with Jacques P?pin and Isaac Mizrahi": 290000.0,
#  'People Who Inspire Us': 350000.0,
#  'Lady Panther "Bow or Bullet"': 500000.0,
#  'GazillionairesLife: a new way to Buy, Sell, and Trade! (Canceled)': 450000.0,
#  'Flight Experience - Kansas City (Canceled)': 500000.0,
#  'The Bill Nye Film': 650000.0,
#  'The Brooklyn Album': 1000000.0,
#  'KosLo- Fixing the broken car buying experience! (Canceled)': 1000000.0,
#  "LumiaNova, The world's largest, greenest, light concert!": 900000.0,
#  '"PEOPLE OF ..." inspiring people with beautiful stories!': 510000.0,
#  'Heli Harbor': 1200000.0,
#  'SpeedyLeafer': 700000.0,
#  'We, the Enslaved': 250000.0,
#  'Sweet Apple Pie Fries!': 250000.0,
#  'Shroud of the Avatar: Forsaken Virtues': 1000000.0,
#  'Point of Sale Project': 1000000.0,
#  'UJ-Innovative Fashion Designer': 1000000.0,
#  '??AP Computer Science and Mobile App School': 879000.0,
#  'Save Gawker.com': 500000.0,
#  '" A STORY ABOUT LOVE "  motion picture production': 1200000.0,
#  'The BeltFctry': 300000.0,
#  'Major Motion Picture "Asarum" (Canceled)': 300000.0,
#  'Have a dish named after you': 350000.0,
#  '"Desperate Command" Showcase Short Motion Picture': 290000.0,
#  'Android Device Monitoring - Catch Me If You Can': 250000.0,
#  'The Flea Trap': 740000.0,
#  'Help me get a 3D Immersive Naruto MMORPG created': 600000.0,
#  'A SWEET BAKERY WITH A VIEW': 250000.0,
#  'Experience "Galaxy"': 750000.0,
#  'The Newest Hottest Spike Lee Joint': 1250000.0,
#  'Stream Live Party': 500000.0,
#  "Studio Lot 13's The Scream Scene Theater": 250000.0,
#  'Chad Hart is Not So Vain - Straight V Gay makeover': 350000.0,
#  'Landshape Modeling and Design': 500000.0,
#  'Galactic Raiders feature-Kickstarter': 229200.0,
#  'Three60 Beer brewing System': 400000.0,
#  'The Road to Forgiveness': 1500000.0,
#  'mr.dj': 1000000.0,
#  'Soriba or Goods Doer': 250000.0,
#  'Complete Snake River Treehouse Pizza and Grill': 250000.0,
#  'Oindexter (Canceled)': 500000.0,
#  'Tales & Realms - the Beta Project': 3000000.0,
#  'G1: Innovative Dental Design': 325000.0,
#  'The Sweet Spot': 500000.0,
#  'Evoljeans-Iwear Company': 250000.0,
#  'G.H.O.S.T. / Hydrogen On-Demand': 1400000.0,
#  'The Strike Pitcher Software Program': 300000.0,
#  'Verbi Security': 696800.0,
#  'DRUMPF THE MUSICAL': 3500000.0,
#  'The Illuminated Messiah Bible & Art Exhibit': 350000.0,
#  'Health Sidekick APP and SIte': 2500000.0,
#  'Independent By Choice - Advocating A New Political Model': 250000.0,
#  'Cinefex Classic Collection for iPad': 217500.0,
#  'Jesus Christ!': 1000000.0,
#  'Kybernan Holographic Gaming Network': 100000000.0,
#  'LeBron James Redemption Statue': 1000000.0,
#  'Bosses Affiliated sneaker and clothing line': 250000.0,
#  "Zion's Creative Arts Center (Canceled)": 2000000.0,
#  'Save Me From This Upcoming Election': 500000.0,
#  'The Two-Front War': 800000.0,
#  'Setupshopz.com': 600000.0,
#  'Zurvive! A Live Action Survival Horror Game': 250000.0,
#  'RoboTar Guitar Chord Robot helps you Play Guitar! (Canceled)': 230000.0,
#  'Vixen': 2500000.0,
#  'equal rights for all campaign': 35000000.0,
#  'YOURECG': 500000.0,
#  'Midnight Nectar': 3500000.0,
#  'Project Snowstorm': 500000.0,
#  "Mustard Pancakes - Oogleberry's Journey Home": 1400000.0,
#  'Byson farm and eatery': 500000.0,
#  'The Clambake: The History of the Pebble Beach Pro-Am': 1350000.0,
#  'The Manson Obsession (Canceled)': 2000000.0,
#  'Dolphinese! Talk to Dolphins in their own native language!': 1171000.0,
#  '2d3D HierSwipe': 527000.0,
#  'A Hard Place': 350000.0,
#  'Monkey Light: The most effective way to be seen on your bike': 220000.0,
#  'CourEntertainment LLC\'s Video Game Project: "Space-opolis"': 2464670.0,
#  'Ekawa I - The Motion Picture': 8000000.0,
#  'Morons4Money - Set Bob On Fire (Suspended)': 1000000.0,
#  'GAMMA Fight Club': 5759042.0,
#  'Black On Black Murder in America! Stoping This Madness!': 250000.0,
#  'Sit and Be Fit - Keep The Dream Alive (Canceled)': 250000.0,
#  'THE AFTERLIFE FILES': 500000.0,
#  "Timothy Zahn's Parallax (turn-based 4X galactic conquest)": 350000.0,
#  'Save the Victory Theatre (Canceled)': 1000000.0,
#  'One Good Deed (Canceled)': 500000.0,
#  'Suburban Invasion: The Ultimate Off-Road Experience': 225000.0,
#  'Technerd.com Needs support International AD campaign': 1500000.0,
#  'Clean2Clear': 250000.0,
#  'Ultimate Rideshare': 275000.0,
#  'Indie film - Think "Days of Thunder" on a motorcycle track!': 1400000.0,
#  'The Confidant': 10000000.0,
#  'SAVING COUNCIL': 797267.0,
#  'Junior CMS: the scaffolding to rebuild the web a better way.': 250000.0,
#  "Ron Maxwell's Civil War Classics (Canceled)": 250000.0,
#  'The Blue Vale: A Tabletop RPG in Augmented Reality': 350000.0,
#  "Martin Delgado's Flying Techniques, (2)": 4000000.0,
#  'NOMOREGMOFOODS': 400000.0,
#  'U-Dot Creative Space System': 999000.0,
#  'Adventure through the Amazon River (Canceled)': 475000.0,
#  'G POD X 1': 275000.0,
#  'CellVenom - Non Lethal Personal Defense for iPhone 6/6S/7': 250000.0,
#  'The Russian Sharks': 250000.0,
#  'Open Source Technology Improvement Fund (OSTIF)': 388000.0,
#  'The Via Heartbeat Bracelet': 300000.0,
#  'The BEST WATER EVER 7.8 PH Highest all Natural water.': 250000.0,
#  'Karma Plus: The Socially Conscious Network & Kindness App': 300000.0,
#  'The Momentum Dryer & UpFlow Technology (Consumer Model)': 650000.0,
#  'GeoSpot........Never get lost......&........Always be found.': 275000.0,
#  'The Secret Ninja Cat World Mobile App': 562000.0,
#  'BRIDEGROOM - An American Love Story': 300000.0,
#  'Custom Water-Cooled Laptop Backplate': 500000.0,
#  'Godless Artist': 300000.0,
#  'Turntables Of House': 6000000.0,
#  'Cape Cinema': 250000.0,
#  'PartyPronto': 1500000.0,
#  'By The End Of This Book': 500000.0,
#  'ABB Movie Project': 1400000.0,
#  'Crescent Moon Spirits LLC': 450000.0,
#  'Greek Authentic  virgin olive oil from Greece to Usa for All': 300000.0,
#  "Ambrosia'a Boone / Midnight's Nectar": 3500000.0,
#  'Pono Music - Where Your Soul Rediscovers Music': 800000.0,
#  "Braddah's Island Style - fresh kitchen & grill": 5000000.0,
#  'Save Nature': 2000000.0,
#  'A Caribbean Internet Radio Station operating like "NPR"': 250000.0,
#  'Terahex 1000 Bot (Hexacopter/Multirotor/Drone) (Canceled)': 250000.0,
#  'Ending climate change, one vegan at a time': 500000.0,
#  'Space Trucker': 300000.0,
#  'Milkbe Strollers The Safest Most Modern stroller.': 500000.0,
#  'Blackspace - Plan. Dig. Defend. Survive.': 350000.0,
#  'The Veronica Mars Movie Project': 2000000.0,
#  'So-Gnar Sounds stereo infused lifejacket and sports apparel': 250000.0,
#  'Sushiman School': 500000.0,
#  "Zombie Mike now that he's dead he's really living": 235000.0,
#  'The Nicholas Project  - Keeping Christ in Christmas': 1085000.0,
#  'Amazing America - Tornado Alley (Canceled)': 450000.0,
#  'The Golf Farm': 380000.0,
#  "It's The GOD Complex": 372625.0,
#  'JOIN THE MOVEMENT TO GROW MORSO (Canceled)': 250000.0,
#  'WAR - 4 player Custom built colectors chess set (Oak & Glas)': 500000.0,
#  'SPREADSHEET HEAVEN': 500000.0,
#  'Forgotten Warriors': 350000.0,
#  'Overshadowed - The Search for the USS Cyclops': 275000.0,
#  'F-35 Lightning II, Modern Combat Sim: Single Player and MMOG': 250000.0,
#  'Pepe & Lucas: The Animated Series': 350000.0,
#  "Paco's Tacos": 600000.0,
#  'Pontiac Aztek Conservation and Customizing': 500000.0,
#  'The Alone (Canceled)': 350000.0,
#  'The Cones of Dunshire (Canceled)': 300000.0,
#  'Los Angeles Laser Tag': 435500.0,
#  'The Book of Self Help: Depression Quest': 250000.0,
#  'The Kabul Golf Club': 350000.0,
#  'OVERLOAD - The Ultimate Six-Degree-of-Freedom Shooter': 300000.0,
#  'OXYGEN FROM BOOKS (Canceled)': 1000000.0,
#  'From Foster To Family': 275000.0,
#  'The Revival of Royal Ringball ~ A Sport of the Maya Gods.': 995000.0,
#  'Supercar Garageï¿½:  Stage One': 250000.0,
#  'Watscene': 500000.0,
#  'Crime Busters (Canceled)': 400000.0,
#  'Death Match': 2000000.0,
#  'Myythic: The Buried Temple of Alimar (Canceled)': 250000.0,
#  'Theory of the Evolution of the Moral Idiot': 500000.0,
#  'Laser Headphones (Canceled)': 250000.0,
#  'Mother Earth Needs Our Help': 250000.0,
#  'Commercial Beekeeping and honey farm start up. (Canceled)': 300000.0,
#  'Localvotion: Connecting farms to LOCAVORES': 250000.0,
#  'Cocktail Sideshow Bar': 250000.0,
#  'Worlds Air': 2257037.0,
#  '"Q Sheba" (Canceled)': 500000.0,
#  "Masters of the Kingdomï¿½Don't just visit Disneyland, play it!": 250000.0,
#  'Wasted Entertainment round 2': 5000000.0,
#  'New Music!!!': 1000000.0,
#  'CULT COUNTY by Renegade Kid': 580000.0,
#  'Thundercats!!!! Hooooooooooooo!!!!!!!! (Canceled)': 1000000.0,
#  'Immediate Political Accountability Resource (I-PAR)': 3000000.0,
#  'Blood Will Tell': 2500000.0,
#  'Grandeur Paradigm': 650000.0,
#  'SIAAB Technology - No more deaths!': 1000000.0,
#  'Hawkendoo: The Telepathic Spy': 1000000.0,
#  "DJ's Country Saloon": 550000.0,
#  'The Katy Incident': 750000.0,
#  'Window- Virtual Reality Holocaust Education': 1000000.0,
#  'The Risen': 675000.0,
#  'HEX MMO Trading Card Game': 300000.0,
#  'VOLUNTEERED': 2000000.0,
#  'RED CARD: A FILM ABOUT FIFA (Canceled)': 600000.0,
#  'Maebar Restaurant & Lounge': 584000.0,
#  'ARANAGA STUDIOS.': 1000000.0,
#  'Zero Point!! Game Console Upgrade to the Future': 999000.0,
#  'PA Golf American Red Carpet Launch Project/Event': 300000.0,
#  'THE GREAT COMET - An Independent Film': 250000.0,
#  'Chronicles of Elyria - Epic Story MMORPG with Aging & Death': 900000.0,
#  'Destroy only copy of new Wu-Tang Album': 6000000.0,
#  'Pueblo Underground Theater (Canceled)': 400000.0,
#  'Two Sides for a Mirror': 250000.0,
#  'Cool Roofs! Let the phenomenon begin!': 5250000.0,
#  "Mama's: Sweet & Healthy!": 800000.0,
#  '50 Shades of Silver Hair and Socks': 300000.0,
#  "Shipper's Market": 300000.0,
#  'Penny Arcade Sells Out': 250000.0,
#  'The Tymeblock Experience (Canceled)': 400000.0,
#  'JOHN SKIPP\'S "ROSE": THE 3D ZOMBIE PUPPET MUSICAL!': 250000.0,
#  "'Line Pirates Facebook Game": 374484.0,
#  'Voxpop': 250000.0,
#  'New AviCulture System': 450000.0,
#  'Realms of Goldesia - Player-Driven Virtual Reality MMORPG': 900000.0,
#  'gig': 1000000.0,
#  "Gamer's Hotel USA": 500000.0,
#  'The Historical Hall of Fame (Canceled)': 250000.0,
#  'marko. Clothing Launch (Canceled)': 400000.0,
#  'Cancelled :(': 500000.0,
#  '"The Wrecking Crew" The Untold Story of Rock & Roll Heroes': 250000.0,
#  'Help us create Possession The Old Story movie like no other!': 350000.0,
#  'Redeye Visuals': 450000.0,
#  'Johnny Rocketfingers 3': 390000.0,
#  'Community Farm': 500000.0,
#  'An American Veterans Greatest Road Trip of North America': 525000.0,
#  'The Dash ï¿½ Wireless Smart In Ear Headphones': 260000.0,
#  'The REAL Trump University - The Art of the STEAL': 250000.0,
#  'Mass Produce': 300000.0,
#  'AMBROV X: A Story-Driven, Science Fiction RPG (Canceled)': 500000.0,
#  'Restaurants digital menu app with language translation': 400000.0,
#  '"I SAVE LIVES" The App To Protect Aircraft From Small Drones': 330000.0,
#  "New Year's Gala for unveiling of Historic Opera Relic": 300000.0,
#  'THOR GENESIS - A Desilu Studios Production': 500000.0,
#  'World War 3 the Fight of the People': 500000.0,
#  'Supercar Garageï¿½ TV': 265000.0,
#  'The Legend of the Lost Rose by Pazzaria Productions': 250000.0,
#  'Raising Money For My Book To Get On Film!': 1000000.0,
#  'The Prophet Chronicles: Redemption - Pre-Production': 500000.0,
#  'Zig': 250000.0,
#  'LifeCool - Amazing lifesaving cooler for all boats!': 400000.0,
#  "SPLIT: The World's Only Earbuds with no Strings Attached": 435000.0,
#  'FILM w/ THORA BIRCH, HEATHER MATARAZZO, JENNIFER ELISE COX': 5000000.0,
#  'BIP Records, support the movement and it will support you.': 250000.0,
#  'Environmentally Safe Storm Drains + Parking Lots': 2500000.0,
#  'All Race Matters! (Canceled)': 250000.0,
#  'Recording Studio': 300000.0,
#  'Candy store & Deli in Clearwater Beach': 500000.0,
#  '"FRIGHT PLAN"': 345000.0,
#  'Rebuild Enzo Ferrari': 2500000.0,
#  'Electric Vehicle Self Charging system - Drive and Charge': 300000.0,
#  'Sweet Mara film project': 1000000.0,
#  'Calypso Music Festival': 250000.0,
#  'Nomasoak-The first truly portable hot tub': 350000.0,
#  "Salvators' Winery & Restaurant": 3500000.0,
#  'Mariner Farms: local, closed loop, organic food production.': 250000.0,
#  'GetActive': 210000.0,
#  'Somewhere in Time (Canceled)': 300000.0,
#  'Larceny Lock: Make Your Door Kick-in Proof': 500000.0,
#  'Helpeddle': 210000.0,
#  'Ceramic Pie Studios': 325000.0,
#  'Endless Dreams Pillow / Adjustable pillow': 650000.0,
#  'Salt Bill Home Beer Kit': 425000.0,
#  'Kingdom of Oberon': 400000.0,
#  'Shark Tooth Edger': 475000.0,
#  'Bazadee Sports (Canceled)': 2000000.0,
#  'SANTA MARIA: THE FIRST VOYAGE': 700000.0,
#  'Help us fund a new hobby shop for everyone': 276855.0,
#  'Earth Sheltered Homes Nightly Rental Project': 300000.0,
#  'Trail Of Fears Haunted House': 500000.0,
#  'Miss Wisenheimer and the Aliens': 822996.0,
#  'The First Iditarod: The Amazing Dogs & Their Mushers': 235000.0,
#  "sonoro Cubo: World's First All-In-One SmartHome Audio System": 250000.0,
#  '5 Degrees of Separation (Canceled)': 1000000.0,
#  'Beyond the Pillowed Bed': 250000.0,
#  'Camp Oak Hallows - A Wizarding World Experience': 1000000.0,
#  'Conscious Conscience': 1000000.0,
#  'King of the Dead - A Horror / Comedy Movie': 250000.0,
#  "Mom, I'm Marrying a Hybrid; Don't Tell Dad Yet!": 1000000.0,
#  'Is That a Gun in Your Pocket ...?': 2200000.0,
#  'Road to the 2014 World Shoot': 300000.0,
#  'Thimbleweed Park: A New Classic Point & Click Adventure!': 375000.0,
#  'Batman v Iron Man : The Jokers [fan film project] (Canceled)': 490000.0,
#  'Fremont Performing Arts Center (Canceled)': 300000.0,
#  'Connect Games': 1000000.0,
#  'Otaku Kingyo Seiiki (Canceled)': 270000.0,
#  'Treagan': 1000000.0,
#  'Oreggio.com': 300000.0,
#  'HULLABALOO TN ROCK FESTIVAL': 700000.0,
#  "Sparkbox the World's Most Powerful Portable Power Source": 350000.0,
#  'Louisiana Cr?ole restaurant in the heart of Miami Beach': 250000.0,
#  'Blue Elephants': 400000.0,
#  'Freshg?rd: Organic for all! (Canceled)': 500000.0,
#  'Nhuad Single Hand Video Game Controllers': 300000.0,
#  'Save Movie Madness': 250000.0,
#  'CineBlock 2.0 (Canceled)': 1500000.0,
#  'Plaza Capcom USA': 5000000.0,
#  'THE ESSENCE OF BACON': 250000.0,
#  'Fan Made Platinum Artist (Canceled)': 1000000.0,
#  'Diabetic Simple': 250000.0,
#  "The Sweet Fox Fudge Open's It's Doors": 380000.0,
#  'Health & Fitness Meal by ProteinPharm': 400000.0,
#  'Cast Irons Steakhouse': 900000.0,
#  'Pink me! Bakery (Canceled)': 300000.0,
#  '"PAQUP & GO!" - Discover Your Groups Destinations!': 500000.0,
#  '"Snap Cover" for an Electrical outlet': 350000.0,
#  'Crafting Series "Enjoy the Moments" by Megan Elizabeth': 500000.0,
#  'Higgy: Your Real Person, Travel Advisor and Agent App': 400000.0,
#  'The Climate Zombies': 1000000.0,
#  'Adam 2.0   From Young Man to Real Man': 320000.0,
#  'Game Studio': 480000.0,
#  'The Super Amazing Hummus Micro-Factory': 389900.0,
#  'UNTITLED RTA MOVIE': 300000.0,
#  "Momma Lilly's Cafe": 300000.0,
#  'MyWorld': 600000.0,
#  'Xybears The Last Heroes': 1000000.0,
#  'Tribes of the CaveFan': 1672000.0,
#  'WOODSHOP': 250000.0,
#  'The Ugly Mexican (Canceled)': 250000.0,
#  'modds': 500000.0,
#  'Local Area Drone Dispatch and Authorization System (LADDAS)': 300000.0,
#  'The Arts of Performing': 250000.0,
#  'Jesus Vs The Dragons': 10000000.0,
#  'BlinkScan: Capture All of the Image & None of the Background': 295000.0,
#  'Gobuggs the movie': 419666.0,
#  'Destiny 1': 781325.0,
#  'Dragonï¿½s Lair: The Movie (Canceled)': 550000.0,
#  'The Barette Kaddy, Colorful, Rotating Storage Unit': 250000.0,
#  'Scum Gear-Apparel For The Rest Of Us': 5000000.0,
#  'Project Ravensdale (Canceled)': 500000.0,
#  '"MATA HARI"': 1200000.0,
#  'Underground Art and Conservation Museum in Midcoast Maine': 900000.0,
#  'DREAMER- Full-Length Motion Picture of a Modern-Day Joseph': 375000.0,
#  "ZTE 'Project CSX' Phone - Hands Free, Eye Tracking Device": 500000.0,
#  'Taiga Legacy - providing exotic trees & fruits year-round': 450000.0,
#  'Key of Fate': 2900000.0,
#  'coreXtreme Afterburner Core Bodyweight Fitness Machine': 1000000.0,
#  'Renaissance Men': 1000000.0,
#  "Martin Delgado's Flying Techniques": 2000000.0,
#  'SANTO 7.13.15 G.M.O. Movie (Canceled)': 2000000.0,
#  'Who Am I? Where Do I Come From? The Swiderski Story': 275000.0,
#  'Getting down to business': 300000.0,
#  'The Return Of The Bell Witch Movie': 100000000.0,
#  'Howling Moon Productions Film': 400000.0,
#  '"FIRST DOG: SECOND TERM"': 250000.0,
#  'ZION (Canceled)': 500000.0,
#  'MotoRide quickely on demand with low cost in one click app!': 1200000.0,
#  'Unfinished Business:  A Ghost Story': 250000.0,
#  'Ride Share': 3000000.0,
#  'Shaolin Time Master/Back To Urantia': 237000.0,
#  'TREE60 - Christmas Tree Stand "Rotate & Decorate"': 375000.0,
#  'RenFest Comedy TV Show (Canceled)': 365000.0,
#  'Ube WiFi Connected Smart Light Dimmer': 280000.0,
#  "You could own my face...and why wouldn't you want that?": 250000.0,
#  'Patient Zero: Outbreak': 1200000.0,
#  'Magic Mountain Farm (Canceled)': 450000.0,
#  'LUV & PERVERSITY IN THE EAST VILLAGE': 500000.0,
#  'Data Stocks\'s "Money Machine" Mobile Application': 300000.0,
#  'UNITY THE MOVIE': 800000.0,
#  'Northwoods Gaming Project': 5000000.0,
#  'The Gamers: Hands of Fate': 320000.0,
#  'Shadow Mansion': 750000.0,
#  'Family Fueled- A Trans Am Reality Show': 780000.0,
#  'Fighting out of Tijuana': 385000.0,
#  'Robot Fighting Championship': 500000.0,
#  'Black Ice - How blacks enslaved invented the game of hockey': 375000.0,
#  'CANDY MOUNTAIN': 250000.0,
#  '4ARMS': 227000.0,
#  'Dungeonforge': 300000.0,
#  'The Book on Comedy': 1000000.0,
#  'Nichol Alexander': 500000.0,
#  'Discovering Hope': 1000000.0,
#  'Shades of Gray': 500000.0,
#  'PALOMINAS': 350000.0,
#  'Lateralus | the debut album': 7316000.0,
#  'Hydro Electrical stand-alone generator complex.': 325000.0,
#  'LeisureMaps': 500000.0,
#  'Jump Start Racing (Canceled)': 250000.0,
#  'GermBGone (Canceled)': 500000.0,
#  'Pathfinder: Kingmaker': 500000.0,
#  'With the Web in the Front': 1000000.0,
#  'HOPE! Making fantasy a reality....': 300000.0,
#  'Homeland': 2000000.0,
#  'Eazy Coin': 1000000.0,
#  'The Mice War': 298000.0,
#  'Sculpture set to be given to Woodstock NY THE BAND set': 350000.0,
#  'The Dogwood Inn: A New B&B for an Old River Town!': 430000.0,
#  'Raising My SuperKidsï¿½! Mobile Social Game (Canceled)': 500000.0,
#  'Avenge (Canceled)': 1000000.0,
#  'The Life (Canceled)': 1250000.0,
#  'Seeds of Our Future Farms': 250000.0,
#  'Black Duct - An innovation in heating and cooling systems.': 300000.0,
#  'koi farm': 1500000.0,
#  'Two Guys SpaceVenture - by the creators of Space Quest': 500000.0,
#  'Oregon Ducks.  A Love Story (Canceled)': 1200000.0,
#  'The Everyday Backpack, Tote, and Sling': 500000.0,
#  'EXFYRE!!! THE FIRE EXTINGUISHER THAT NO OTHER CAN COMPARE.': 500000.0,
#  'Kuthoomi App': 1000000.0,
#  'DrYvr- A feature length horror/thriller film': 250000.0,
#  'Sidemen: Long Road To Glory - Narrated by Marc Maron': 225000.0,
#  'BUILDING BRIDGES - Film Based on a True Story (Canceled)': 500000.0,
#  'Lets Build/Buy a house (Canceled)': 350000.0,
#  'CARE365': 500000.0,
#  'Shin Do Kumat? - Return of Ancient Ones': 300000.0,
#  '[Project: Monolith]': 225000.0,
#  'Tha Life': 1500000.0,
#  'Kvits - Technology that Improves Dining': 300000.0,
#  "World's 1st,,Finest ARTISAN Crafted water waits for you.": 250000.0,
#  '21st CENTURY MEDICAL PRACTICE SYSTEM THAT CHANGES THE WORLD': 250000.0,
#  'The Journal Library': 6000000.0,
#  'THE MESSAGE': 500000.0,
#  'Obduction': 1100000.0,
#  'Aviation Brewing Company': 300000.0,
#  'Funding for a 1950s Museum in Tampa Bay (Canceled)': 1000000.0,
#  'Vir-Sec, SecureCommunique with SecureAxcess. Cyber Security': 250000.0,
#  'LifeBox is a global humanitarian effort solving world hunger': 250000.0,
#  'Cushitepedia ï¿½ A free online encyclopedia of Nubian History': 300000.0,
#  'Infinity Blade Chronicles': 480000.0,
#  'StreetGodz- Body Enhancing Shoe': 500000.0,
#  '1979 REVOLUTION: Black Friday': 395000.0,
#  'The Electronic Kids Gym or The Electronic Family Gym': 850000.0,
#  'HOWEVER YOU MOVE': 700000.0,
#  "Enjoy The Old Children's Home: Historic Preservation": 1100000.0,
#  'Deathfire: Ruins of Nethermore RPG': 390000.0,
#  'The War On Truth - Documentary': 250000.0,
#  'MONSTER FEST (Canceled)': 225000.0,
#  'Oblivion Seed': 1000000.0,
#  'DREAD: Book of Lovecraft': 250000.0,
#  'The Surrender Movie Project': 1000000.0,
#  "Rose and Thistle Cafe'": 300000.0,
#  'The Chronicles Of The Green Mile Club': 250000.0,
#  'No Blood...Just Diamonds...American Woodie in Sierra Leone': 450000.0,
#  'A Place to Gather Writing Center, LLC': 300000.0,
#  'Choices': 350000.0,
#  'Interactive Smart Tables': 250000.0,
#  ...}

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import re

regex  = re.compile(r"Sport*")
cursor = collection_kickstarter.find({"name":regex})

# %%
sports = [e["name"] for e in cursor]
print("Nombre :", len(sports))
print("Extrait:", sports[:6])
# Out:
# Nombre : 330
# Extrait: ['Sportswear range', 'Mount Systems for Recreation Sports & Film (GoPro) Lighting', 'E-GoBox: Revolutionary Sports Capsule Dispenser', 'Tactical Bottle Opening Hot Sauce Dispensing Spork', 'Biz Sports Weekly', 'Hugodrawings Sports Wear']
